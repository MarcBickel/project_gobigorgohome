# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
import pickle

# %%
openfoodfact_data_path = "./data/en.openfoodfacts.org.products.csv"       #1 023 451 lignes !!
off_tar_path = "data/en.openfoodfacts.org.products.tar.xz"
test_path = "./data/test2.csv"

# %%
number_of_col = []
for i in range(175):
    number_of_col.append(i)

# %%
in_path = "data/en.openfoodfacts.org.products.tar.xz" #Path where the large file is
out_path = "data" #Path to save the pickle files to
chunksize = 100000 #size of chunks relies on your available memory

i=0
for chunk in pd.read_csv(in_path, sep='\t', usecols=number_of_col, chunksize=chunksize):
    out_file = out_path + "/off_chunk_{}.pkl".format(i+1)
    i+=1
    with open(out_file, "wb") as f:
        pickle.dump(chunk,f,pickle.HIGHEST_PROTOCOL)
# Out:
# /home/samuel/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,24,25,26,28,44,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/samuel/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,26,28,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/samuel/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/samuel/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,44) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
import glob
pickle_path = "data" #Same Path as out_path i.e. where the pickle files are

data_p_files=[]
for name in glob.glob(pickle_path + "/off_chunk_*.pkl"):
   data_p_files.append(name)


df = pd.DataFrame([])
for i in range(len(data_p_files)):
    df = df.append(pd.read_pickle(data_p_files[i]),ignore_index=True)

# %%
df = pd.read_pickle("data/off_chunk_1.pkl")
df2 = pd.read_pickle("data/off_chunk_2.pkl")
df3 = pd.read_pickle("data/off_chunk_3.pkl")
df4 = pd.read_pickle("data/off_chunk_4.pkl")
df5 = pd.read_pickle("data/off_chunk_5.pkl")

# %%
df = df.append(df2).append(df3).append(df4)

# %%
df.shape
# Out:
# (400000, 175)

# %%
df[df.code == 16000139626]
# Out:
#                code                                                url  \
# 15623   16000139626  http://world-en.openfoodfacts.org/product/0016...
# 244388  16000139626  http://world-en.openfoodfacts.org/product/1600...
#
#                            creator   created_t      created_datetime  \
# 15623   openfoodfacts-contributors  1539366893  2018-10-12T17:54:53Z
# 244388                     kiliweb  1561900458  2019-06-30T13:14:18Z
#
#         last_modified_t last_modified_datetime  \
# 15623        1539366936   2018-10-12T17:55:36Z
# 244388       1561900458   2019-06-30T13:14:18Z
#
#                           product_name generic_name quantity  ...  \
# 15623                         Cheerios          NaN  15.2 oz  ...
# 244388  Cheerios Oat Crunch (Cinnamon)          NaN      NaN  ...
#
#        carbon-footprint-from-meat-or-fish_100g nutrition-score-fr_100g  \
# 15623                                      NaN                     NaN
# ...

# %%
df.head()
# Out:
#                    code                                                url  \
# 0         0000000000017  http://world-en.openfoodfacts.org/product/0000...
# 1         0000000000031  http://world-en.openfoodfacts.org/product/0000...
# 2  00000000001111111111  http://world-en.openfoodfacts.org/product/0000...
# 3         0000000000123  http://world-en.openfoodfacts.org/product/0000...
# 4         0000000000178  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0                     kiliweb  1529059080  2018-06-15T10:38:00Z
# 1                    isagoofy  1539464774  2018-10-13T21:06:14Z
# 2  openfoodfacts-contributors  1560020173  2019-06-08T18:56:13Z
# 3                     kiliweb  1535737982  2018-08-31T17:53:02Z
# 4                     kiliweb  1542456332  2018-11-17T12:05:32Z
#
#    last_modified_t last_modified_datetime           product_name generic_name  \
# ...
